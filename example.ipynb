# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\kolli\Documents\Naresh IT\data files\Visadataset.csv")

# %%
visa_df['education_of_employee'].value_counts()
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
n=visa_df['education_of_employee'].unique()
n
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
count=[]
for i in n:
    can=visa_df['education_of_employee']==i
    val=len(visa_df[can])
    count.append(val)
count
emp=pd.DataFrame(zip(n,count),columns=['employee','count'])
emp
# Out:
#       employee  count
# 0  High School   3420
# 1     Master's   9634
# 2   Bachelor's  10234
# 3    Doctorate   2192

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = {
    'employee': ['emp1', 'emp2', 'emp3'],
    'count': [10, 20, 15]
}
emp = pd.DataFrame(data)
print(emp)
plt.bar(emp['employee'], emp['count'])
plt.title("Bar chart")
plt.xlabel("education of employees")
plt.ylabel("count")
plt.show()
# Out:
#   employee  count
# 0     emp1     10
# 1     emp2     20
# 2     emp3     15

# %%
import matplotlib.pyplot as plt

plt.bar('employee', 'count', data=emp)
plt.title("Bar chart")
plt.xlabel("education of employees")
plt.ylabel("count")
plt.show()

# %%
#for seaborn we will use countplot method
#it requires only main dataframe data
#add column name and dataframe
#automatically y-axis will take the coiunt of the catagorical data

# %%
sns.countplot(data=visa_df,x="education_of_employee")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure plt and ylabel are correctly defined
sns.countplot(data=visa_df, y="education_of_employee")
plt.xlabel("education")
plt.ylabel("count of") 
plt.show()

# %%
#for seaborn we will use countplot
#matplot.pyplot we will use bar

# %%
n=visa_df["education_of_employee"].value_counts()
keys=n.keys()
keys
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object', name='education_of_employee')

# %%
plt.title("bar graph")
ax=n.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %%
#for the pie chart we will use the pie method in the matplotlib.pyplot package

# %%
names='kolli','kolli2','kollki3'
DF=pd.DataFrame(names,columns=['names'],index=[1,2,3])

# %%
DF['JOBS']=['DS','ML','DL']
DF
# Out:
#      names JOBS
# 1    kolli   DS
# 2   kolli2   ML
# 3  kollki3   DL

# %%
DF.shape
# Out:
# (3, 2)

# %%
DF.take([1])
# Out:
#     names JOBS
# 2  kolli2   ML

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(x)

# Create a 2x2 grid of subplots
plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Sine')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Cosine')

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Tangent')

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Exponential')

plt.tight_layout()  # Adjust subplots to fit into figure area.
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(x)

# Using subplot
plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Sin(x)')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Cos(x)')

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Tan(x)')

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Exp(x)')

plt.tight_layout()
plt.show()

# Using subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

axs[0, 0].plot(x, y1)
axs[0, 0].set_title('Sin(x)')

axs[0, 1].plot(x, y2)
axs[0, 1].set_title('Cos(x)')

axs[1, 0].plot(x, y3)
axs[1, 0].set_title('Tan(x)')

axs[1, 1].plot(x, y4)
axs[1, 1].set_title('Exp(x)')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# %%
banking=pd.read_csv(r"C:\Users\kolli\Documents\Naresh IT\data files\bank-additional.csv",sep=';')

# %%
banking.head(2)
# Out:
#    age          job  marital    education default housing loan    contact  \
# 0   30  blue-collar  married     basic.9y      no     yes   no   cellular
# 1   39     services   single  high.school      no      no   no  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         fri  ...         2    999         0  nonexistent         -1.8
# 1   may         fri  ...         4    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.313       5099.1  no
# 1          93.994          -36.4      4.855       5191.0  no
#
# [2 rows x 21 columns]

# %%
banking=pd.read_csv(r"C:\Users\kolli\Documents\Naresh IT\data files\loan_data.csv")
banking.head(2)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
